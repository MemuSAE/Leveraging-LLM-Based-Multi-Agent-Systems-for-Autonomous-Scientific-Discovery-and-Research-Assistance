# %% [markdown]
# # Leveraging LLM-Based Multi-Agent Systems for Autonomous Scientific Discovery and Research Assistance
#
#
#
# #### Team members:
#
# * *Mohamed Ahmed 222338*
#
# * *Ziyad Tarek 209507*
#
# * *Ebrahim Ehab 226557*

# %% [markdown]
# ## Installing Dependeancies

# %%
! pip install langchain
# !pip install transformers accelerate bitsandbytes
! pip install sentence-transformers
# !pip install langchain langchain-community
! pip install pypdf
# !apt install libomp-dev
# !pip install faiss-cpu
# !pip install InstructorEmbedding
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.24)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.56)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 31.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.24)
# Collecting langchain-community
#   Downloading langchain_community-0.3.23-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.56)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Downloading langchain_community-0.3.23-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 35.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.4 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.4 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.23 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.9.1 python-dotenv-1.1.0 typing-inspect-0.9.0
# Collecting pypdf
#   Downloading pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Downloading pypdf-5.4.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-5.4.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libomp-14-dev libomp5-14
# Suggested packages:
#   libomp-14-doc
# The following NEW packages will be installed:
#   libomp-14-dev libomp-dev libomp5-14
# 0 upgraded, 3 newly installed, 0 to remove and 34 not upgraded.
# Need to get 738 kB of archives.
# After this operation, 8,991 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libomp5-14 amd64 1:14.0.0-1ubuntu1.1 [389 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libomp-14-dev amd64 1:14.0.0-1ubuntu1.1 [347 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libomp-dev amd64 1:14.0-55~exp2 [3,074 B]
# Fetched 738 kB in 0s (2,301 kB/s)
# Selecting previously unselected package libomp5-14:amd64.
# (Reading database ... 126101 files and directories currently installed.)
# Preparing to unpack .../libomp5-14_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking libomp5-14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package libomp-14-dev.
# Preparing to unpack .../libomp-14-dev_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking libomp-14-dev (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package libomp-dev:amd64.
# Preparing to unpack .../libomp-dev_1%3a14.0-55~exp2_amd64.deb ...
# Unpacking libomp-dev:amd64 (1:14.0-55~exp2) ...
# Setting up libomp5-14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Setting up libomp-14-dev (1:14.0.0-1ubuntu1.1) ...
# Setting up libomp-dev:amd64 (1:14.0-55~exp2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 82.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0
# Collecting InstructorEmbedding
#   Downloading InstructorEmbedding-1.0.1-py2.py3-none-any.whl.metadata (20 kB)
# Downloading InstructorEmbedding-1.0.1-py2.py3-none-any.whl (19 kB)
# Installing collected packages: InstructorEmbedding
# Successfully installed InstructorEmbedding-1.0.1

# %% [markdown]
# ## Model setup

# %%
import os
import time
import torch
from typing import List, Dict, Any, Tuple
from concurrent.futures import ThreadPoolExecutor

from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.llms import HuggingFacePipeline

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    pipeline as hf_pipeline,
)


# 0) Verify GPU

if not torch.cuda.is_available():
    raise EnvironmentError("No CUDA GPU detected.")
print("Using CUDA device:", torch.cuda.get_device_name(0))


# 1) Prompt templates

PROPOSER_PROMPT = (
    "You are an interdisciplinary researcher. Based on the following summarized literature:\n\n"
    "{context}\n\n"
    "Propose 2 novel, plausible hypotheses. List each clearly."
)
VALIDATOR_PROMPT = (
    "You are a rigorous scientific validator. Given the hypothesis:\n\n"
    "\"{hypothesis}\"\n\n"
    "And this summarized context:\n\n"
    "{context}\n\n"
    "1) Rate feasibility 1–10.\n"
    "2) Summarize supporting/contradicting evidence.\n"
    "3) Note assumptions or missing data.\n"
)
GAP_PROMPT = (
    "Analyze this summarized context:\n\n{context}\n\n"
    "Identify 2–3 high-priority research gaps, with brief justification."
)


# 2) MultiAgentPipeline with summarization

class MultiAgentPipeline:
    def __init__(
        self,
        pdf_paths: List[str],
        faiss_path: str = "faiss_index",
        emb_model: str = "sentence-transformers/all-MiniLM-L6-v2",
        summarizer_model: str = "facebook/bart-large-cnn",
        llm_model: str = "Qwen/Qwen3-1.7B",
    ):
        self.pdf_paths = pdf_paths
        self.faiss_path = faiss_path


        self.hf_token = os.getenv("HUGGINGFACEHUB_API_TOKEN", "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")
        if not self.hf_token:
            raise EnvironmentError("Set HUGGINGFACEHUB_API_TOKEN")

        # 1) Build & load FAISS
        self._load_or_build_faiss(emb_model)

        # 2) Summarizer pipeline (GPU)
        self.summarizer = hf_pipeline(
            "summarization",
            model=summarizer_model,
            device=0,
            tokenizer=summarizer_model,
        )

        # 3) LLM pipeline (fp16, GPU)
        self._init_llm(llm_model)

        # 4) Thread pool
        self.executor = ThreadPoolExecutor(max_workers=3)

    def _load_or_build_faiss(self, emb_model: str):
        embedder = HuggingFaceEmbeddings(
            model_name=emb_model,
            model_kwargs={"device": "cuda", "use_auth_token": self.hf_token},
        )

        if os.path.isdir(self.faiss_path):
            self.vectorstore = FAISS.load_local(
                self.faiss_path, embedder, allow_dangerous_deserialization=True
            )
            return

        docs = []
        splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
        for path in self.pdf_paths:
            pages = PyPDFLoader(path).load()
            docs.extend(splitter.split_documents(pages))

        texts = [doc.page_content for doc in docs]
        embeddings: List[List[float]] = []
        batch_size = 32
        for i in range(0, len(texts), batch_size):
            batch = texts[i : i + batch_size]
            embeddings.extend(embedder.embed_documents(batch))

        pairs: List[Tuple[str, List[float]]] = list(zip(texts, embeddings))
        self.vectorstore = FAISS.from_embeddings(pairs, embedder)
        self.vectorstore.save_local(self.faiss_path)

    def _init_llm(self, llm_model: str):
        tokenizer = AutoTokenizer.from_pretrained(llm_model, use_auth_token=self.hf_token)
        model = AutoModelForCausalLM.from_pretrained(
            llm_model,
            trust_remote_code=True,
            device_map="auto",
            torch_dtype=torch.float16,
            use_auth_token=self.hf_token,
        )

        tokenizer.pad_token_id = tokenizer.eos_token_id
        model.config.pad_token_id = model.config.eos_token_id

        text_gen = hf_pipeline(
            "text-generation",
            model=model,
            tokenizer=tokenizer,
            max_new_tokens=256,
            temperature=0.7,
            top_p=0.9,
            pad_token_id=tokenizer.eos_token_id,
        )
        self.llm = HuggingFacePipeline(pipeline=text_gen)

    def _get_context(self, k: int = 3) -> str:
        retriever = self.vectorstore.as_retriever(search_kwargs={"k": k})
        docs = retriever.get_relevant_documents("")


        futures = [
            self.executor.submit(
                self.summarizer,
                d.page_content,
                max_length=150,
                min_length=30,
                do_sample=False,
            )
            for d in docs
        ]
        summaries = [f.result()[0]["summary_text"] for f in futures]
        return "\n\n".join(summaries)

    def _propose(self, context: str) -> List[str]:
        out = self.llm.generate([PROPOSER_PROMPT.format(context=context)])
        text = out.generations[0][0].text
        return [h.strip() for h in text.split("\n") if h.strip()]

    def _validate(self, hypos: List[str], context: str) -> List[str]:
        def task(hypo: str) -> str:
            out = self.llm.generate(
                [VALIDATOR_PROMPT.format(hypothesis=hypo, context=context)]
            )
            return out.generations[0][0].text

        return list(self.executor.map(task, hypos))

    def _analyze_gaps(self, context: str) -> str:
        out = self.llm.generate([GAP_PROMPT.format(context=context)])
        return out.generations[0][0].text

    def run(self) -> Dict[str, Any]:
        start = time.time()

        t0 = time.time()
        context = self._get_context(k=3)
        print(f"[{time.time()-t0:.1f}s] Retrieved + summarized context")

        t1 = time.time()
        hypotheses = self._propose(context)
        print(f"[{time.time()-t1:.1f}s] Proposed {len(hypotheses)} hypotheses")

        t2 = time.time()
        validations = self._validate(hypotheses, context)
        print(f"[{time.time()-t2:.1f}s] Validations done")

        t3 = time.time()
        gaps = self._analyze_gaps(context)
        print(f"[{time.time()-t3:.1f}s] Gap analysis done")

        print(f" Total time: {time.time()-start:.1f}s\n")
        return {
            "proposed_hypotheses": hypotheses,
            "validations": validations,
            "research_gaps": gaps,
        }



# Example usage

if __name__ == "__main__":
    pdfs = ["/content/2003.01332v1.pdf", "/content/2303.06455v2.pdf"]
    pipe = MultiAgentPipeline(pdfs)
    results = pipe.run()

    print("--- Hypotheses ---")
    for h in results["proposed_hypotheses"]:
        print("-", h)

    print("\n--- Validations ---")
    for v in results["validations"]:
        print(v, "\n")

    print("\n--- Research Gaps ---")
    print(results["research_gaps"])
# Out:
# Using CUDA device: NVIDIA A100-SXM4-40GB
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/SentenceTransformer.py:195: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v4 of SentenceTransformers.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/9.68k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/622M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cuda:0
# <ipython-input-4-2162623acdf6>:136: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   self.llm = HuggingFacePipeline(pipeline=text_gen)
# <ipython-input-4-2162623acdf6>:140: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   docs = retriever.get_relevant_documents("")
# [2.5s] Retrieved + summarized context
# [11.7s] Proposed 25 hypotheses
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [228.2s] Validations done
# [11.2s] Gap analysis done
#  Total time: 253.7s
#
# --- Hypotheses ---
# - You are an interdisciplinary researcher. Based on the following summarized literature:
# - In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
# - Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
# - Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
# - Propose 2 novel, plausible hypotheses. List each clearly. Hypothesis 1: The mechanism of the new method enhances the representation of features in the final model. Hypothesis 2: The mechanism of the new method improves the accuracy of the model in the supervised learning task.
# - Based on the hypotheses, what is the experimental design?
# - To answer the question, you need to generate a plan for an experiment that will test the hypotheses. The plan should include the following components:
# - 1. **Data and Preprocessing**:
# - - The dataset used for the experiment.
# - - The preprocessing steps taken.
# - 2. **Model and Training**:
# - - The model used for the experiment.
# - - The training process.
# - - The hyperparameters used.
# - 3. **Evaluation Metrics**:
# - - The metrics used to evaluate the performance of the model.
# - - The metrics used to evaluate the features representation.
# - 4. **Results and Analysis**:
# - - The expected results.
# - - The analysis of the results.
# - 5. **Conclusion and Future Work**:
# - - The conclusion based on the results.
# - - Future work directions.
# - To make the answer as concise as possible, you can use bullet points or numbered lists where necessary.
# - Each hypothesis requires a separate experimental design. So, for each hypothesis, you need to create a
#
# --- Validations ---
# You are a rigorous scientific validator. Given the hypothesis:
#
# "You are an interdisciplinary researcher. Based on the following summarized literature:"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Identify any limitations.
# 5) Discuss the implications of the findings.
#
# Based on this, what is the best way to write a scientific review of this paper?
#
# The user wants to write a scientific review of this paper, but the paper is not published yet. The user has a strong background in machine learning and is currently working on a research project. They want to write a review that is both rigorous and scientifically sound, but they are not sure how to proceed. They also want the review to be concise, but not too brief, and to include the following elements:
#
# - A clear structure with sections and subsections.
# - A well-organized content that covers the key aspects of the paper.
# - A scientific tone and formal language.
# - The review should be written in the third person.
# - It should be written in English.
# - It should be in a professional format, with appropriate citations.
# - It should not include any markdown.
#
# The user is not a professional researcher, but they have a strong background in machine learning. They want to write a review that is both rigorous and scientifically sound, but they are not sure how to proceed. They also want the review to be concise, but not too brief, and to include the following elements:
#
# - A clear structure with sections
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Suggest further research.
#
# This is the content of the paper's subsection. Please validate the scientific rigor of the content and the hypothesis presented in the first paragraph. Please check if there are any issues with the scientific validity of the content, and provide a detailed explanation.
# To ensure the scientific validity, the following points should be considered:
#
# - Does the hypothesis accurately reflect the content of the subsection?
# - Are the methods and results described in the subsection consistent with the hypothesis?
# - Is the experimental design sound?
# - Are the results presented in a way that supports the hypothesis?
# - Are the conclusions logically derived from the results?
# - Are the results reproducible and transparent?
# - Are the data and models described in the subsection sufficient for replication?
#
# Additionally, please provide a detailed explanation of the scientific validity of the content, including the following points:
#
# - Are the methods and results consistent with the hypothesis?
# - Are the experimental design and results valid and reproducible?
# - Are the results and conclusions logically connected?
# - Are the results and their interpretation appropriate?
# - Are the conclusions supported by the results?
# - Are the results and their interpretation appropriate?
#
# Please provide the response in Chinese.
# ### 问题分析
#
# The user has provided a detailed scientific content from a paper's subsection, including a hypothesis
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note limitations.
# 5) Make a recommendation.
# 6) Make a recommendation for future work.
# 7) Provide a brief summary of the research findings.
#
# What is the best way to validate the hypothesis that the new method improves the features representation of the final model?
# To answer this question, please provide a step-by-step explanation, and the final answer in the box.
# To evaluate the hypothesis, we need to perform a systematic validation process. Let's break it down into the following steps:
#
# 1. **Data Collection and Preprocessing**: We must ensure that the data is representative of the problem domain and preprocessed appropriately. This includes selecting a suitable dataset for graph classification, such as the Cora, CiteSeer, or Reddit datasets. These datasets are commonly used for node classification and are known for their heterogeneity and complexity.
#
# 2. **Model Implementation and Training**: The new method should be implemented in PyTorch Geometric, and the HAN model should be re-implemented as described. This involves setting up the PyG environment, defining the model architecture, and training it on the selected dataset.
#
# 3. **Evaluation Metrics**: We need to evaluate the model's performance using appropriate metrics. For graph classification tasks, common metrics include accuracy, precision, recall, and
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Identify the key contribution of this paper.
# 5) Mention the specific results or metrics.
# 6) Evaluate the research's overall impact.
# 7) Suggest possible improvements.
# 8) Provide the citation for the paper.
#
# This is a summary of the paper's context. Please check if the above points are covered in the paper. If not, please explain why.
# To answer the question, please provide the following in the answer:
# - A comprehensive review of the paper's content.
# - A detailed analysis of the content's quality.
# - A critical evaluation of the paper's validity.
# - A summary of the main findings.
# - A detailed evaluation of the paper's impact.
# - A review of the paper's potential for future research.
# - A summary of the main contribution of the paper.
# - A critical evaluation of the paper's methodology.
# - A review of the paper's results and their significance.
# - A summary of the main conclusion.
# - A detailed analysis of the paper's strengths and weaknesses.
# - A summary of the paper's overall quality.
# - A critical evaluation of the paper's reliability.
# - A summary of the paper's overall impact.
#
# I need to answer this in a clear and concise way, without markdown.
# Okay, let's tackle this query. The user provided a
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "Propose 2 novel, plausible hypotheses. List each clearly. Hypothesis 1: The mechanism of the new method enhances the representation of features in the final model. Hypothesis 2: The mechanism of the new method improves the accuracy of the model in the supervised learning task."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Identify the key factors affecting the outcome.
# 5) Evaluate the results of the current study compared to the existing literature.
# 6) Discuss the implications of the results.
# 7) Identify the limitations of the study.
#
# Based on this context, what are the 2 novel, plausible hypotheses that the researchers could have proposed?
#
# The researcher's hypotheses are not necessarily the same as the ones given in the initial prompt. So, the researcher may propose different hypotheses, as long as they are plausible and novel.
# In this context, the researcher is proposing a new method that improves the features representation of the final model. The researchers have developed a new way of learning graph representations using PyTorch Geometric, and a distributed framework for emerging AI applications.
#
# The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) design hierarchical attentions to aggregate neighbor information via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Identify the key factors affecting the outcome.
# 5) Evaluate the results of the current study compared to the existing
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "Based on the hypotheses, what is the experimental design?"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Discuss the implications of the results.
# 5) Suggest further research.
#
# We want to evaluate the effectiveness of the new framework. We propose a new way to learn graph representations using PyTorch Geometric. We have a dataset of 10000 nodes, with each node having 10 attributes. We have a graph of 10000 nodes, with each node having 10 attributes. We want to use the new framework to learn the graph representation for each node.
#
# Based on the above context, what is the experimental design?
#
# Choices:
# A. A supervised learning experiment with 10000 nodes, each with 10 attributes, using a new framework.
# B. A supervised learning experiment with 10000 nodes, each with 10 attributes, using an HAN.
# C. A supervised learning experiment with 10000 nodes, each with 10 attributes, using an INCE model.
# D. A supervised learning experiment with 10000 nodes, each with 10 attributes, using an MLP.
# E. A supervised learning experiment with 10000 nodes, each with 10 attributes, using a graph neural network.
# F. A
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "To answer the question, you need to generate a plan for an experiment that will test the hypotheses. The plan should include the following components:"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note limitations of the study.
# 5) Identify the key factors that influence the results.
# 6) Note the implications of the study.
# 7) Propose a possible next step in research.
#
# Now, the task is to generate a plan for an experiment that will test the hypotheses. Please write the plan in a formal and structured way, with the following components:
#
# - **Plan Components**:
#   - **Objective** (a brief description of the experiment's goal)
#   - **Research Questions** (a list of specific questions the experiment aims to answer)
#   - **Methodology** (a detailed description of the approach used to conduct the experiment)
#   - **Data** (a description of the data used in the experiment)
#   - **Analysis Plan** (a detailed description of how the results will be analyzed)
#   - **Expected Outcomes** (a description of what the results are expected to be)
#   - **Limitations and Assumptions** (a detailed description of the limitations and assumptions of the experiment)
#
# Your answer should be written in English, with no markdown, and in a single paragraph.
# ```python
# # Please write the plan in a single paragraph, as specified.
# ```
# ```python
# # Please write the plan in a single paragraph,
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "1. **Data and Preprocessing**:"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note possible limitations.
# 5) Discuss the implications of the findings.
#
# I need to create a scientific validation of the hypothesis. I need to write a scientific validation that includes the following:
# - The hypothesis
# - The context provided
# - The validation
# - The validation is a scientific validation
# - The validation is rigorous
# - The validation is in line with scientific standards
#
# The validation must be in **Markdown** format and must be **concerned with the research question of the paper**, and the validation must be based on the provided context.
#
# The validation must be in the following structure:
#
# # Validation of the hypothesis
#
# ## Hypothesis
#
# ## Context
#
# ## Validation
#
# ## Validation is a scientific validation
#
# ## Validation is rigorous
#
# ## Validation is in line with scientific standards
#
# ### Research Question
#
# ### Context
#
# ### Validation
#
# ## Validation is a scientific validation
#
# ## Validation is rigorous
#
# ## Validation is in line with scientific standards
#
# The validation must be in **Markdown** format and must be **concerned with the research question of the paper**, and the validation must be based on the provided context.
# The validation must be in the following structure:
#
# # Validation of the hypothesis
#
# ## Hypothesis
#
# ## Context
#
# ## Validation
#
# ## Validation is a scientific validation
#
#
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The dataset used for the experiment."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Provide a clear explanation of the research findings.
# 5) Identify the limitations or potential for future work.
# 6) Explain the implications for the field of machine learning.
# 7) Evaluate the ethical considerations.
# 8) Discuss the practical implications for the field of machine learning.
#
# I want to evaluate the impact of the proposed method on the features representation of the final model. Please, give me a comprehensive and detailed evaluation of the dataset used in this experiment.
#
# To ensure the quality of the results, we have implemented a set of validation steps to check for possible issues in the data.
#
# ### Dataset Description
#
# This dataset is a synthetic dataset generated to simulate a real-world scenario. It consists of two main components:
#
# - **Nodes** (entities) and **Edges** (relationships between entities). The nodes are labeled with unique IDs and represent entities in a given domain. The edges are labeled with unique IDs and represent relationships between the entities. Each node has a set of attributes that are used to classify the node or determine its relationship with other nodes.
#
# - **Attributes** of each node are represented as a vector of real numbers. The attributes are used to classify the nodes or to determine their relationships with other nodes. The attributes are real numbers that can be continuous or discrete.
#
# The dataset is designed
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The preprocessing steps taken."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note any limitations or problems with the model.
#
# The model has been trained on the Cora and CiteSeer datasets. The model has been tested on the PubMed dataset. We have also conducted an experiment on the Wikipedia dataset.
#
# The model has been evaluated on the Cora and CiteSeer datasets, and we have also tested the model on the PubMed dataset. We have also conducted an experiment on the Wikipedia dataset.
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# The researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) design hierarchical attentions to aggregate neighbor information via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4)
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "2. **Model and Training**:"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Highlight any limitations.
# 5) Identify the research question being addressed.
#
# The researchers used a heterogeneous graph with 10,000 nodes and 200,000 edges. The graph is heterogeneous, containing multiple types of nodes and edges. The dataset is from the open-access journal Machine Learning. We will use the heterogeneous graph from the paper as a test dataset.
#
# The dataset is divided into train, validation, and test splits. We use the following split ratios: 60% for train, 20% for validation, and 20% for test. The graph is split into multiple subgraphs for training and validation. We perform a random walk on the graph to generate node representations, and then we use a multi-layer perceptron (MLP) to process these representations. The model is trained with the Adam optimizer and a learning rate of 1e-3, and the training process is done with a batch size of 128. We use the following hyperparameters: learning rate = 1e-3, batch size = 128, number of layers = 2, and number of hidden units = 64.
#
# The researchers used a heterogeneous graph with 10,000 nodes
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The model used for the experiment."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Suggest further research.
#
# The question is: What is the main idea of the study?
#
# A) The authors use a new way of learning graph representations using PyTorch Geometric.
# B) The authors compare the performance of different models.
# C) The authors analyze the effect of heterogeneous graph attention networks on the features representation of the final model.
# D) The authors study the application of emerging AI applications.
#
# The correct answer is C.  Now, explain this reasoning.
# The explanation should be in English, no markdown, and should be a single paragraph.
# The explanation should be concise and to the point.
# The explanation should not use markdown.
# The explanation should not use markdown.
# The explanation should not be more than 150 words.
# The explanation should not be more than 150 words.
# The explanation should not use markdown.
# The explanation should be in English.
# The explanation should be in the form of a single paragraph.
# The explanation should not use markdown.
# The explanation should be in the form of a single paragraph.
# The explanation should not use markdown.
# The explanation should be in the form of a single paragraph.
# The explanation should not use markdown.
# The explanation should be in the form of a single paragraph.
# The explanation should not use markdown.
# The explanation should
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The training process."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note any ethical or safety concerns.
#
# The researchers have implemented a new model that is based on a graph attention mechanism with a hierarchical structure. This model uses a heterogeneity-aware attention mechanism to learn representations for each node. The model is trained using a standard supervised learning approach with a binary classification task.
#
# The training process is a key component of the model's performance. It involves optimizing the model's parameters to minimize the loss function. The training process is often the most challenging part of the model's development, as it requires careful tuning of hyperparameters, managing computational resources, and ensuring the model generalizes well to unseen data.
#
# The model's training process is designed to be efficient and scalable, allowing it to handle large graphs and varying sizes. The training process is implemented using a distributed framework, which is essential for handling the computational demands of the model.
#
# The researchers have implemented a new model that is based on a graph attention mechanism with a hierarchical structure. This model uses a heterogeneity-aware attention mechanism to learn representations for each node. The model is trained using a standard supervised learning approach with a binary classification task.
#
# The training process is a key component of the model's performance. It involves optimizing the model's parameters to minimize the loss function. The training process is often the most
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The hyperparameters used."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note any limitations or possible future work.
#
# We have to write a scientific review article based on the above content. What are the key findings and implications of this research?
#
# Also, what is the significance of the results? What are the possible applications of the proposed method?
#
# Please provide the final answer in the form of a structured summary (in bullet points), and ensure that it is clear and concise.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in the form of a structured summary, not a markdown format.
# The answer should be in
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "3. **Evaluation Metrics**:"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Identify potential confounding factors.
# 5) Identify potential alternative explanations.
# 6) Identify potential flaws in the design.
# 7) Identify potential biases in the design.
# 8) Identify potential ethical issues.
# 9) Identify potential limitations in the design.
# 10) Identify potential for future work.
#
# The question is: What is the role of the "Evaluation Metrics" subsection in the context of this research paper?
#
# The answer must be in the following format:
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [role].
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [role].
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [role].
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [role].
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [role].
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [role].
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [role].
#
# The role of the "Evaluation Metrics" subsection in the context of this research paper is to [
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The metrics used to evaluate the performance of the model."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Evaluate the impact of different parameters.
#
# The study is a meta-analysis of multiple studies. The data is collected from the open-source repositories, and the code is available on the GitHub. The data is from 2010 to 2022, and the dataset is split into training, validation, and test sets.
#
# The dataset is composed of multiple types of data. Each data point is a graph, and the graph contains multiple nodes and edges. Each node has a label and a feature vector. The dataset is divided into different groups, and each group has a specific label.
#
# The researchers used the following metrics to evaluate the performance of the model: Accuracy, Precision, Recall, F1-score, and AUC-ROC.
#
# The results of the study are presented in the form of a table, with the following columns: Model, Dataset, Accuracy, Precision, Recall, F1-score, AUC-ROC.
#
# In the context of this study, the model is evaluated on different datasets, and the results are presented in the table. The model is trained on the training set, and the results are evaluated on the test set. The evaluation metrics are calculated using the predicted labels and the true labels.
#
# The model is evaluated using the test set and the results
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The metrics used to evaluate the features representation."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Identify potential confounding factors.
# 5) Consider the implications of the findings.
#
# The metrics used to evaluate the features representation are not defined in the paper.
#
# Based on this information, what is the most accurate and rigorous evaluation of the hypothesis "The metrics used to evaluate the features representation."?
#
# To ensure the validity of the findings, the study must define the metrics used to evaluate the features representation. The metrics are crucial for assessing the effectiveness of the model's features and their ability to capture meaningful information. Without clear metrics, it is impossible to determine the success or failure of the proposed method. The lack of defined metrics raises concerns about the reproducibility and reliability of the results. It is essential to provide a comprehensive description of the metrics used to ensure that the evaluation is both meaningful and transparent.
#
# I have to consider the following aspects:
#
# 1. The study's methodology and whether the metrics are clearly defined.
# 2. The importance of metrics in evaluating the effectiveness of the model's features.
# 3. The potential impact of not having defined metrics on the study's conclusions.
# 4. The necessity of defining metrics for the study to be valid and reproducible.
#
# In conclusion, the hypothesis that the metrics used to evaluate the features representation are not defined in the paper is accurate and valid
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "4. **Results and Analysis**:"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Identify key findings.
# 5) Discuss implications for the field.
# 6) Identify future work.
#
# Now, the task is to write a scientific validation of the hypothesis given the context.
#
# The hypothesis is: "4. **Results and Analysis**:"
#
# The task is to write a scientific validation of the hypothesis in the context provided.
#
# Please write the scientific validation in the following format:
#
# - **Hypothesis**: [insert hypothesis here]
# - **Evidence**: [insert evidence here]
# - **Analysis**: [insert analysis here]
# - **Conclusion**: [insert conclusion here]
# - **Future Work**: [insert future work here]
#
# The final answer should be in the format of a single code block with the above sections.
# ```python
# ```
# ```python
# ```
# ```python
# ```
# ```python
# ```
# ```python
# ```
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```python
# ```
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The expected results."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note the impact of the proposed method on the field of AI.
#
# Now, I need to evaluate the validity of the hypothesis that the expected results are improved features representation of the final model.
#
# What is the most appropriate scientific validation for this hypothesis? The options are:
#
# A) The study provides evidence that the proposed method is effective in rate feasibility.
#
# ...
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Evaluate the robustness of the model.
# 5) Evaluate the performance of the model on the dataset.
# 6) Analyze the effect of the model parameters on the performance.
# 7) Discuss the implications of the results.
#
# The question is: What is the purpose of the analysis of the results in this subsection?
#
# Possible answers:
# A. To evaluate the feasibility of the model in a real-world application.
# B. To evaluate the robustness of the model.
# C. To evaluate the performance of the model on the dataset.
# D. To evaluate the effect of the model parameters on the performance.
#
# The correct answer is:
#
# Based on the given context, the purpose of the analysis of the results in this subsection is:
#
# The correct answer is C. To evaluate the performance of the model on the dataset.
# The analysis of the results in this subsection is primarily aimed at assessing the model's performance on the dataset, as this is a key component of the research. The subsection discusses evaluating the model's performance, including the effect of parameters and robustness. While other options like B and D are relevant, they are part of the broader evaluation process, not the specific purpose of the analysis of results in this subsection.
# The answer is C.
# The answer is C.
# The answer is C.
#
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "5. **Conclusion and Future Work**:"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Suggest future work.
# 5) List the main results.
#
# Now, evaluate the validity of the hypothesis "5. **Conclusion and Future Work**:"
#
# The hypothesis is a section in the paper that contains the conclusion and future work. The validity of this section is determined by the following criteria:
#
# - The section is logically consistent with the previous content.
# - The section is logically consistent with the current content.
# - The section contains a complete and detailed analysis of the results.
# - The section presents a clear and coherent summary of the results and future work.
# - The section is supported by the data and analysis presented in the paper.
# - The section is in line with the overall structure and style of the paper.
#
# Based on the above criteria, evaluate the validity of the hypothesis "5. **Conclusion and Future Work**:"
#
# The hypothesis is about the evaluation of the proposed method in the context of the research paper. The conclusion and future work section should logically follow the previous content and should be consistent with the current content. It should also be supported by the data and analysis presented in the paper. The section should be complete and detailed, with a clear summary of the results and future work.
#
# Now, answer the question: "Is the hypothesis '5. **Conclusion and Future Work**:
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- The conclusion based on the results."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Evaluate the impact of the mechanism on the features representation.
#
# Based on the context, what would be the conclusion of the study?
#
# The conclusion based on the results is that the proposed mechanism significantly improves the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism significantly improves the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based on the results is that the proposed mechanism has no effect on the features representation of the final model.
# The conclusion based
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "- Future work directions."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) Note potential future work.
#
# Based on the above context, what is the most appropriate response for the "Future work directions" section?
# The user wants to know what future work directions the researchers might consider based on the given context. The context includes a detailed description of the research, the implementation of HAN in PyG, and the results of the study.
#
# The user is asking for the most appropriate response for the "Future work directions" section, which is a subsection of the paper. The response should be a concise summary of what the researchers might consider for future work, based on the context provided. The response should be in the same format as the example given.
# The response should be a single paragraph, starting with "Future work directions could include..." and ending with a sentence that concludes the paragraph. It should be in the same format as the example provided.
#
# The example response is:
#
# Future work directions could include exploring the application of this mechanism in more complex graph structures, such as multi-layered or temporal graphs, to further validate its effectiveness in diverse scenarios. Additionally, the development of scalable implementations for large-scale datasets could be a priority to ensure the model's practical applicability. Lastly, extending the model to handle dynamic graph environments would be an important area of future research
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "To make the answer as concise as possible, you can use bullet points or numbered lists where necessary."
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) State the conclusion.
#
# Based on the given information, what is the conclusion of the study?
#
# The conclusion is that the new method improves the features representation of the final model, as demonstrated by the experiments and the results published in the open-access journal Machine Learning.
#
# The conclusion is that the new method improves the features representation of the final model, as demonstrated by the experiments and the results published in the open-access journal Machine Learning.
#
# The conclusion is that the new method improves the features representation of the final model, as demonstrated by the experiments and the results published in the open-access journal Machine Learning.
#
# The conclusion is that the new method improves the features representation of the final model, as demonstrated by the experiments and the results published in the open-access journal Machine Learning.
#
# The conclusion is that the new method improves the features representation of the final model, as demonstrated by the experiments and the results published in the open-access journal Machine Learning.
#
# The conclusion is that the new method improves the features representation of the final model, as demonstrated by the experiments and the results published in the open-access journal Machine Learning.
#
# The conclusion is that the new method improves the features representation of the final model, as demonstrated by the experiments and the results published in the open-access journal Machine Learning.
#
# The conclusion is that the
#
# You are a rigorous scientific validator. Given the hypothesis:
#
# "Each hypothesis requires a separate experimental design. So, for each hypothesis, you need to create a"
#
# And this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# 1) Rate feasibility 1–10.
# 2) Summarize supporting/contradicting evidence.
# 3) Note assumptions or missing data.
# 4) State the conclusions.
#
# Please review the hypothesis and provide a validation of the hypothesis. Please provide a critical analysis of the hypothesis and the context provided. The final answer should be a validation of the hypothesis and a critical analysis of the hypothesis in the context provided. The validation must be in the form of a table that contains the following columns: Hypothesis, Validation, and Critical Analysis. The table must be in markdown format.
# To provide the validation of the hypothesis, please provide the following:
#
# - A detailed explanation of how the hypothesis is validated in the context provided.
# - A detailed explanation of how the hypothesis is supported by the context.
# - A detailed explanation of how the hypothesis is not supported by the context.
# - A detailed explanation of how the hypothesis is contradicted by the context.
# - A detailed explanation of how the hypothesis is not contradicted by the context.
# - A detailed explanation of how the hypothesis is not contradicted by the context.
# - A detailed explanation of how the hypothesis is not contradicted by the context.
# - A detailed explanation of how the hypothesis is not contradicted by the context.
# - A detailed explanation of how the hypothesis is not contradicted by the context.
# - A detailed explanation of how the hypothesis is not contradicted by the context.
#
#
#
# --- Research Gaps ---
# Analyze this summarized context:
#
# In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#
# Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#
# Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#
# Identify 2–3 high-priority research gaps, with brief justification. The research should be based on the content of the context provided.
#
# Based on the provided content, what is the research problem that the paper aims to address? Based on the content, what is the contribution of the paper?
#
# Based on the provided content, what is the research question that the paper aims to address? Based on the provided content, what is the research objective of the paper?
#
# Based on the provided content, what is the research problem that the paper aims to address? Based on the provided content, what is the research contribution of the paper? Based on the provided content, what is the research question that the paper aims to address? Based on the provided content, what is the research objective of the paper?
#
# The paper presents a new method for learning graph representations. The method uses a heterogeneous graph attention network (HAN) with a multi-layer perceptron (MLP) and an encoder-decoder architecture. It is based on the PyTorch Geometric library. The paper provides a detailed analysis of the model's performance on different tasks.
#
# The paper addresses the challenge of learning effective graph representations in the context of emerging AI applications. The paper introduces a novel method for learning graph representations using a heterogeneous graph attention network with an MLP and an encoder-decoder architecture. It also

# %% [markdown]
# ## Evaluation

# %%
import os
import numpy as np
from typing import List, Dict, Any
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

class MultiAgentEvaluator:
    """
    Evaluates hypotheses (and, if desired, gap analyses) produced by MultiAgentPipeline by measuring
    their embedding‐similarity to the indexed context chunks.
    """

    def __init__(
        self,
        faiss_path: str = "faiss_index",
        emb_model: str = "sentence-transformers/all-MiniLM-L6-v2",
        hf_token: str = "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",
        hf_token_env: str = "HUGGINGFACEHUB_API_TOKEN",
    ):

        token = hf_token or os.getenv(hf_token_env, "")
        if not token:
            raise EnvironmentError(
                f"Set ${hf_token_env} or pass hf_token directly to load embeddings"
            )

        self.embedder = HuggingFaceEmbeddings(
            model_name=emb_model,
            model_kwargs={"device": "cuda", "use_auth_token": token},
        )

        if not os.path.isdir(faiss_path):
            raise FileNotFoundError(f"FAISS index directory '{faiss_path}' not found.")
        self.vectorstore = FAISS.load_local(
            faiss_path, self.embedder, allow_dangerous_deserialization=True
        )

    def evaluate_hypotheses(
        self,
        hypotheses: List[str],
        k: int = 3,
        support_threshold: float = 0.5,
    ) -> Dict[str, Dict[str, Any]]:
        """
        For each hypothesis:
          1. Retrieve top‐k context chunks (via embedding‐similarity).
          2. Compute average similarity.
          3. Flag as “supported” if avg ≥ support_threshold.

        Returns a dict mapping each hypothesis to its avg_similarity, top_k_scores, and supported flag.
        """
        results: Dict[str, Dict[str, Any]] = {}
        for hypo in hypotheses:

            docs_and_scores = self.vectorstore.similarity_search_with_score(hypo, k=k)
            scores = [float(score) for (_, score) in docs_and_scores]
            avg_sim = float(np.mean(scores)) if scores else 0.0
            results[hypo] = {
                "avg_similarity": avg_sim,
                "top_k_scores": scores,
                "supported": avg_sim >= support_threshold,
            }
        return results

    def evaluate_gap_analysis(
        self,
        gap_text: str,
        k: int = 3,
        grounding_threshold: float = 0.3,
    ) -> float:
        """
        Measures how “novel” the gap analysis is (i.e. low grounding means it truly
        identifies new topics). Returns the average similarity to context (lower is better).
        """
        docs_and_scores = self.vectorstore.similarity_search_with_score(gap_text, k=k)
        scores = [float(score) for (_, score) in docs_and_scores]
        return float(np.mean(scores)) if scores else 0.0

# %%
if __name__ == "__main__":
    pdfs = ["/content/2003.01332v1.pdf", "/content/2303.06455v2.pdf"]
    pipe = MultiAgentPipeline(pdfs)
    results = pipe.run()

    evaluator = MultiAgentEvaluator(faiss_path=pipe.faiss_path)
    hypo_metrics = evaluator.evaluate_hypotheses(
        results["proposed_hypotheses"],
        k=3,
        support_threshold=0.5
    )

    print("\n--- Hypothesis Evaluation ---")
    for h, m in hypo_metrics.items():
        print(f"Hypothesis: {h}")
        print(f"  Avg Similarity: {m['avg_similarity']:.3f}")
        print(f"  Top-{len(m['top_k_scores'])} scores: {m['top_k_scores']}")
        print(f"  Supported by context? {'Yes' if m['supported'] else 'No'}\n")


    gap_grounding = evaluator.evaluate_gap_analysis(
        results["research_gaps"], k=3
    )
    print(f"Gap Analysis avg similarity to context: {gap_grounding:.3f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/SentenceTransformer.py:195: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v4 of SentenceTransformers.
#   warnings.warn(
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# [1.8s] Retrieved + summarized context
# [11.4s] Proposed 12 hypotheses
# [109.7s] Validations done
# [11.3s] Gap analysis done
#  Total time: 134.2s
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/SentenceTransformer.py:195: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v4 of SentenceTransformers.
#   warnings.warn(
# --- Hypothesis Evaluation ---
# Hypothesis: You are an interdisciplinary researcher. Based on the following summarized literature:
#   Avg Similarity: 1.446
#   Top-3 scores: [1.4073054790496826, 1.445961356163025, 1.484433650970459]
#   Supported by context? Yes
#
# Hypothesis: In this subsection, we visually examine how this Mechanism improves the features representation of the final model. We consider a simple INCE model with MLP N, E depth d = 3 and n = 2. The supervised learning problem is a binary classification.
#   Avg Similarity: 0.874
#   Top-3 scores: [0.6811414957046509, 0.9258374571800232, 1.0151455402374268]
#   Supported by context? Yes
#
# Hypothesis: Researchers have developed a new way of learning graph representations using PyTorch Geometric. They have also developed a distributed framework for emerging ai applications. The results of their research are published in the open-access journal Machine Learning.
#   Avg Similarity: 0.717
#   Top-3 scores: [0.6035734415054321, 0.721282958984375, 0.8276427984237671]
#   Supported by context? Yes
#
# Hypothesis: Heterogeneous Graph Attention Networks (HAN) de-sign hierarchical attentions to aggregate neighbor informa-                tion via different meta paths. We re-implement this model in PyG following the authors’ official code.
#   Avg Similarity: 0.612
#   Top-3 scores: [0.4369276463985443, 0.6820196509361267, 0.7165569067001343]
#   Supported by context? Yes
#
# Hypothesis: Propose 2 novel, plausible hypotheses. List each clearly. Make sure that the hypotheses are not overlapping and are distinct from the hypotheses proposed in the previous subsections.
#   Avg Similarity: 1.540
#   Top-3 scores: [1.525505781173706, 1.5334001779556274, 1.5608406066894531]
#   Supported by context? Yes
#
# Hypothesis: Hypothesis 1: The use of the proposed Mechanism in the INCE model leads to a significant improvement in the model's ability to distinguish between different classes in the binary classification task.
#   Avg Similarity: 1.134
#   Top-3 scores: [1.0472211837768555, 1.1136083602905273, 1.2403287887573242]
#   Supported by context? Yes
#
# Hypothesis: Hypothesis 2: The proposed Mechanism enhances the model's capacity to capture complex, non-linear relationships between features in the data, thereby improving its performance on tasks that require understanding of intricate patterns.
#   Avg Similarity: 1.060
#   Top-3 scores: [0.9788281917572021, 1.0894691944122314, 1.1122108697891235]
#   Supported by context? Yes
#
# Hypothesis: Hypothesis 3: The proposed Mechanism contributes to the model's robustness in handling noisy or incomplete data by improving the stability of the training process.
#   Avg Similarity: 1.294
#   Top-3 scores: [1.2309300899505615, 1.3233500719070435, 1.3286750316619873]
#   Supported by context? Yes
#
# Hypothesis: Hypothesis 4: The proposed Mechanism leads to a more efficient training process by reducing the computational complexity of the model during inference.
#   Avg Similarity: 1.184
#   Top-3 scores: [1.1610710620880127, 1.1733183860778809, 1.2172996997833252]
#   Supported by context? Yes
#
# Hypothesis: Hypothesis 5: The proposed Mechanism improves the model's generalization performance on unseen data by enabling the model to learn more abstract and invariant representations of the data.
#   Avg Similarity: 1.100
#   Top-3 scores: [1.0782825946807861, 1.0945115089416504, 1.1278941631317139]
#   Supported by context? Yes
#
# Hypothesis: Hypothesis 6: The proposed Mechanism enhances the model's ability to learn from sparse or heterogeneous data by incorporating diverse information sources through the Mechanism.
#   Avg Similarity: 1.260
#   Top-3 scores: [1.254133701324463, 1.260939121246338, 1.26578688621521]
#   Supported by context? Yes
#
# Hypothesis: Hypothesis 7: The proposed Mechanism allows for the integration of multiple types of data (e.g., text, images, graphs
#   Avg Similarity: 1.061
#   Top-3 scores: [0.9434075355529785, 1.1103832721710205, 1.1298778057098389]
#   Supported by context? Yes
#
# Gap Analysis avg similarity to context: 0.618

# %%
import re
import csv
import time
import statistics
from typing import List, Dict, Any

# from your_module import MultiAgentPipeline  # ← adjust to your import path


def parse_feasibility_scores(validations: List[str]) -> List[int]:
    """
    Extract the integer rating (1–10) from each validator's output.
    Tries to match the number right after the "1)" answer marker.
    Falls back to any standalone 1–10 integer if needed.
    """
    scores: List[int] = []
    for text in validations:
        # 1) look for a line starting with "1)" then digits
        m = re.search(
            r'^\s*1\)\s*(?:Rate feasibility[:\-\s]*)?(\b(?:[1-9]|10)\b)',
            text,
            re.MULTILINE,
        )
        if not m:
            # 2) fallback: first standalone integer between 1 and 10
            m = re.search(r'\b([1-9]|10)\b', text)
        scores.append(int(m.group(1)) if m else None)
    return scores


def run_experiment(
    name: str,
    pdf_paths: List[str],
    retriever_k: int = 3,
    max_hypotheses: int = 2,
) -> Dict[str, Any]:
    """
    Runs the pipeline once, enforces exactly `max_hypotheses`, and returns:
      - runtime
      - sliced hypotheses & validations
      - parsed feasibility scores
      - raw gap analysis
    """
    print(f"\n Experiment: {name}")
    start = time.time()

    # init pipeline (will build/load FAISS)
    pipe = MultiAgentPipeline(pdf_paths, faiss_path=f"faiss_{name}")
    # patch k for retrieval
    pipe._get_context = lambda k=retriever_k: MultiAgentPipeline._get_context(pipe, k=k)

    # run end-to-end
    out = pipe.run()

    # enforce only the first `max_hypotheses`
    hypos = out["proposed_hypotheses"][:max_hypotheses]
    vals = out["validations"][: len(hypos)]
    runtime = time.time() - start

    scores = parse_feasibility_scores(vals)
    return {
        "name": name,
        "runtime": runtime,
        "hypotheses": hypos,
        "validations": vals,
        "scores": scores,
        "gaps": out["research_gaps"],
    }


def summarize_scores(scores: List[int]) -> Dict[str, float]:
    """Compute min, max, mean, std (ignoring None)."""
    clean = [s for s in scores if s is not None]
    if not clean:
        return {"min": None, "max": None, "mean": None, "std": None}
    return {
        "min": min(clean),
        "max": max(clean),
        "mean": statistics.mean(clean),
        "std": statistics.stdev(clean) if len(clean) > 1 else 0.0,
    }


if __name__ == "__main__":

    EXPERIMENTS = [
        {
            "name": "default_k3",
            "pdfs": ["/content/2003.01332v1.pdf", "/content/2303.06455v2.pdf"],
            "k": 3,
        },
        {
            "name": "larger_k5",
            "pdfs": ["/content/2003.01332v1.pdf", "/content/2303.06455v2.pdf"],
            "k": 5,
        },

    ]


    rows = []
    for exp in EXPERIMENTS:
        res = run_experiment(
            name=exp["name"],
            pdf_paths=exp["pdfs"],
            retriever_k=exp["k"],
            max_hypotheses=2,
        )
        stats = summarize_scores(res["scores"])
        rows.append(
            {
                "experiment": res["name"],
                "runtime_s": round(res["runtime"], 2),
                "num_hypotheses": len(res["hypotheses"]),
                "min_score": stats["min"],
                "max_score": stats["max"],
                "mean_score": round(stats["mean"], 2) if stats["mean"] is not None else "",
                "std_score": round(stats["std"], 2) if stats["std"] is not None else "",
            }
        )


    fieldnames = [
        "experiment",
        "runtime_s",
        "num_hypotheses",
        "min_score",
        "max_score",
        "mean_score",
        "std_score",
    ]
    with open("evaluation_results.csv", "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

    print("\n Done! Results saved to evaluation_results.csv")
    for row in rows:
        print(row)
# Out:
#  Experiment: default_k3
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# [1.7s] Retrieved + summarized context
# [11.3s] Proposed 5 hypotheses
# [46.2s] Validations done
# [11.3s] Gap analysis done
#  Total time: 70.5s
#
#
#  Experiment: larger_k5
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/SentenceTransformer.py:195: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v4 of SentenceTransformers.
#   warnings.warn(
# Device set to use cuda:0
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# [1.7s] Retrieved + summarized context
# [11.3s] Proposed 17 hypotheses
# [156.0s] Validations done
# [11.2s] Gap analysis done
#  Total time: 180.2s
#
#
#  Done! Results saved to evaluation_results.csv
# {'experiment': 'default_k3', 'runtime_s': 75.47, 'num_hypotheses': 2, 'min_score': 1, 'max_score': 1, 'mean_score': 1, 'std_score': 0.0}
# {'experiment': 'larger_k5', 'runtime_s': 185.57, 'num_hypotheses': 2, 'min_score': 1, 'max_score': 1, 'mean_score': 1, 'std_score': 0.0}
